# %%
import pymongo
from pymongo import MongoClient
client = MongoClient()
import requests
import threading
import time

api_key = 'vYm9mTUuspeyAWH1v-acfoTlck-tCxwTw9YfCynC'
url = 'https://hxobin8em5.execute-api.us-west-2.amazonaws.com/api/'

sequence_number = 0


#get data from API
response = requests.post(url, json={'api_key': api_key,
                                    'sequence_number': sequence_number})
raw_data = response.json()
import pprint
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(raw_data)
# Out:
# {   '_next_sequence_number': 1907,
#     'data': [   {   'body_length': 4264,
#                     'channels': 0,
#                     'country': 'US',
#                     'currency': 'USD',
#                     'delivery_method': 1.0,
#                     'description': '<p class="MsoNormal" style="margin: 0in '
#                                    '0in 0pt; background: white; '
#                                    'vertical-align: top; mso-outline-level: '
#                                    '1;"><span style="mso-bookmark: '
#                                    'OLE_LINK2;"><span style="mso-bookmark: '
#                                    'OLE_LINK1;"><span style="font-family: '
#                                    'Cambria; color: black; font-size: 10pt; '
#                                    'mso-bidi-font-size: 12.0pt;"><span '
#                                    'style="mso-tab-count: '
#                                    '1;"><strong>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</strong></span></span></span></span></p>\r\n'
#                                    '<p class="MsoNormal" style="margin: 0in '
#                                    '0in 0pt;"><span style="font-family: Arial; '
#                                    'color: black; font-size: '
#                                    '10pt;">&nbsp;</span></p>\r\n'
#                                    '<p class="MsoNormal" style="margin: 0in '
#                                    '0in 0pt;"><span style="font-family: Times '
#                                    'New Roman; font-size: '
#                                    'medium;">Parents,</span></p>\r\n'
#                                    '<p class="MsoNormal" style="margin: 0in '
#                                    '0in 0pt;"><span style="font-size: '
#                                    'medium;"><span style="font-family: Times '
#                                    'New Roman;">This email is intended to '
#                                    'provide you with instructions on how pay '
#                                    'your scout&rsquo;s Circle 10 council '
#                                    'membership fee and Troop 125&rsquo;s '
#                                    'activity fee.<span style="mso-spacerun: '
#                                    'yes;">&nbsp; </span></span></span></p>\r\n'
#                                    '<p class="MsoNormal" style="margin: 0in '
#                                    '0in 0pt;"><span style="font-family: Times '
#                                    'New Roman; font-size: '
#                                    'medium;">&nbsp;</span></p>\r\n'
#                                    '<p class="MsoNormal" style="margin: 0in '
#                                    '0in 0pt;"><span style="text-decoration: '
#                                    'underline;"><span style="font-size: '
#                                    'medium;"><span style="font-family: Times '
#                                    'New Roman;">A Brief '
#                                    'Explanation</span></span></span></p>\r\n'
#                                    '<p class="MsoNormal" style="margin: 0in '
#                                    '0in 0pt;"><span style="font-size: '
#                                    'medium;"><span style="font-family: Times '
#                                    'New Roman;"><span style="mso-spacerun: '
#                                    'yes;">&nbsp;</span>In the past, scouts '
#                                    'paid their own activity fee by way of '
#                                    'battery sales.<span style="mso-spacerun: '
#                                    'yes;">&nbsp; </span>Those that did not '
#                                    'earn the total fee paid the fee balance at '
#                                    'the end of the year.<span '
#                                    'style="mso-spacerun: yes;">&nbsp; '
#                                    '</span>In past two years battery sales '
#                                    'have been dismal, over half the scouts '
#                                    'didn&rsquo;t even participate. The Troop '
#                                    'Committee has decided to separate activity '
#                                    'fee collections from fund raising '
#                                    'events.</span></span></p>\r\n'
#                                    '<p class="MsoNormal" style="margin: 0in '
#                                    '0in 0pt;"><span style="font-family: Times '
#                                    'New Roman; font-size: '
#                                    'medium;">&nbsp;</span></p>\r\n'
#                                    '<p class="MsoNormal" style="margin: 0in '
#                                    '0in 0pt;"><span style="font-size: '
#                                    'medium;"><span style="font-family: Times '
#                                    'New Roman;">We are currently collecting '
#                                    'outstanding fee balances from last year '
#                                    'and fees for the upcoming year.<span '
#                                    'style="mso-spacerun: yes;">&nbsp; '
#                                    '</span>From now on, fees for the up coming '
#                                    'year will be due in September.<span '
#                                    'style="mso-spacerun: yes;">&nbsp; '
#                                    '</span></span></span></p>\r\n'
#                                    '<p class="MsoNormal" style="margin: 0in '
#                                    '0in 0pt;"><span style="font-family: Times '
#                                    'New Roman; font-size: '
#                                    'medium;">&nbsp;</span></p>\r\n'
#                                    '<p class="MsoNormal" style="margin: 0in '
#                                    '0in 0pt;"><span style="text-decoration: '
#                                    'underline;"><span style="font-size: '
#                                    'medium;"><span style="font-family: Times '
#                                    'New Roman;">Payment '
#                                    'Instructions</span></span></span></p>\r\n'
#                                    '<p class="MsoNormal" style="margin: 0in '
#                                    '0in 0pt;"><span style="font-family: Times '
#                                    'New Roman; font-size: medium;">Your total '
#                                    'payment has two components: 1) Last Years '
#                                    'Fee balance, and 2) This Years Fee.<span '
#                                    'style="mso-spacerun: yes;">&nbsp; '
#                                    '</span>You will need to<strong '
#                                    'style="mso-bidi-font-weight: normal;"> '
#                                    'look in the list below to find your '
#                                    'scout&rsquo;s Last Year Fee '
#                                    'Balance.</strong><span '
#                                    'style="mso-spacerun: yes;">&nbsp; '
#                                    '</span>You will be manually entering this '
#                                    'amount in .<span style="mso-spacerun: '
#                                    'yes;">&nbsp; </span>This year&rsquo;s fee '
#                                    'of $140.00 includes the activity fee of '
#                                    '$125 plus the Circle 10 membership fee of '
#                                    '$15.00.<span style="mso-spacerun: '
#                                    'yes;">&nbsp; </span>Scouters and current '
#                                    'Eagle Scouts do not pay the Activity fee, '
#                                    'only the $15 membership fee.</span></p>\r\n'
#                                    '<p class="MsoNormal" style="margin: 0in '
#                                    '0in 0pt;"><span style="font-family: Times '
#                                    'New Roman; font-size: '
#                                    'medium;">&nbsp;</span></p>\r\n'
#                                    '<p class="MsoNormal" style="margin: 0in '
#                                    '0in 0pt;"><span style="font-family: Times '
#                                    'New Roman; font-size: medium;">Please '
#                                    'contact Jim Dorn (214) 676-7400 for '
#                                    'special payment arrangements or to inquire '
#                                    'about scholarships.</span></p>\r\n'
#                                    '<p class="MsoNormal" style="margin: 0in '
#                                    '0in 0pt;"><span style="font-family: Times '
#                                    'New Roman; font-size: '
#                                    'medium;">&nbsp;</span></p>\r\n'
#                                    '<p class="MsoNormal" style="margin: 0in '
#                                    '0in 0pt;">&nbsp;</p>\r\n'
#                                    '<p>&nbsp;</p>',
#                     'email_domain': 'transcended.com',
#                     'event_created': 1347370070,
#                     'event_end': 1349074500,
#                     'event_published': 1347372751.0,
#                     'event_start': 1347375600,
#                     'fb_published': 0,
#                     'has_analytics': 0,
#                     'has_header': None,
#                     'has_logo': 0,
#                     'listed': 'n',
#                     'name': 'SCOUT FEES 2012-2013',
#                     'name_length': 20,
#                     'object_id': 4320780,
#                     'org_desc': '',
#                     'org_facebook': 0.0,
#                     'org_name': 'Troop 125 - Northwest Bible Church',
#                     'org_twitter': 0.0,
#                     'payee_name': '',
#                     'payout_type': 'ACH',
#                     'previous_payouts': [   {   'address': '4419 Northcrest',
#                                                 'amount': 823.86,
#                                                 'country': 'US',
#                                                 'created': '2010-08-26 '
#                                                            '15:11:30',
#                                                 'event': 790023,
#                                                 'name': 'Troop 125',
#                                                 'state': 'TX',
#                                                 'uid': 5447394,
#                                                 'zip_code': '75229'},
#                                             {   'address': '4419 Northcrest',
#                                                 'amount': 1271.61,
#                                                 'country': 'US',
#                                                 'created': '2010-10-01 '
#                                                            '01:10:25',
#                                                 'event': 859165,
#                                                 'name': 'Troop 125',
#                                                 'state': 'TX',
#                                                 'uid': 5447394,
#                                                 'zip_code': '75229'},
#                                             {   'address': '4419 Northcrest',
#                                                 'amount': 1700.24,
#                                                 'country': 'US',
#                                                 'created': '2010-11-05 '
#                                                            '01:10:20',
#                                                 'event': 879089,
#                                                 'name': 'Troop 125',
#                                                 'state': 'TX',
#                                                 'uid': 5447394,
#                                                 'zip_code': '75229'},
#                                             {   'address': '4419 Northcrest',
#                                                 'amount': 1086.24,
#                                                 'country': 'US',
#                                                 'created': '2010-11-19 '
#                                                            '01:11:11',
#                                                 'event': 1002557,
#                                                 'name': 'Troop 125',
#                                                 'state': 'TX',
#                                                 'uid': 5447394,
#                                                 'zip_code': '75229'},
#                                             {   'address': '4419 Northcrest',
#                                                 'amount': 2275.81,
#                                                 'country': 'US',
#                                                 'created': '2010-12-10 '
#                                                            '01:13:03',
#                                                 'event': 1046771,
#                                                 'name': 'Troop 125',
#                                                 'state': 'TX',
#                                                 'uid': 5447394,
#                                                 'zip_code': '75229'},
#                                             {   'address': '4419 Northcrest',
#                                                 'amount': 3564.58,
#                                                 'country': 'US',
#                                                 'created': '2011-01-22 '
#                                                            '01:11:28',
#                                                 'event': 1150087,
#                                                 'name': 'Troop 125',
#                                                 'state': 'TX',
#                                                 'uid': 5447394,
#                                                 'zip_code': '75229'},
#                                             {   'address': '4419 Northcrest',
#                                                 'amount': 3279.96,
#                                                 'country': 'US',
#                                                 'created': '2011-01-29 '
#                                                            '01:12:35',
#                                                 'event': 1124589,
#                                                 'name': 'Troop 125',
#                                                 'state': 'TX',
#                                                 'uid': 5447394,
#                                                 'zip_code': '75229'},
#                                             {   'address': '4419 Northcrest',
#                                                 'amount': 162.52,
#                                                 'country': 'US',
#                                                 'created': '2011-02-05 '
#                                                            '01:12:43',
#                                                 'event': 1240141,
#                                                 'name': 'Troop 125',
#                                                 'state': 'TX',
#                                                 'uid': 5447394,
#                                                 'zip_code': '75229'},
#                                             {   'address': '4419 Northcrest',
#                                                 'amount': 356.13,
#                                                 'country': 'US',
#                                                 'created': '2011-02-18 '
#                                                            '01:12:25',
#                                                 'event': 1264505,
#                                                 'name': 'Troop 125',
#                                                 'state': 'TX',
#                                                 'uid': 5447394,
#                                                 'zip_code': '75229'},
#                                             {   'address': '4419 Northcrest',
#                                                 'amount': 659.5,
#                                                 'country': 'US',
#                                                 'created': '2011-03-11 '
#                                                            '01:13:20',
#                                                 'event': 1356103,
#                                                 'name': 'Troop 125',
#                                                 'state': 'TX',
#                                                 'uid': 5447394,
#                                                 'zip_code': '75229'},
#                                             {   'address': '4419 Northcrest',
#                                                 'amount': 16441.95,
#                                                 'country': 'US',
#                                                 'created': '2011-04-05 '
#                                                            '01:13:34',
#                                                 'event': 1311491,
#                                                 'name': 'Troop 125',
#                                                 'state': 'TX',
#                                                 'uid': 5447394,
#                                                 'zip_code': '75229'},
#                                             {   'address': '4419 Northcrest',
#                                                 'amount': 766.08,
#                                                 'country': 'US',
#                                                 'created': '2011-04-22 '
#                                                            '01:13:05',
#                                                 'event': 1531023,
#                                                 'name': 'Troop 125',
#                                                 'state': 'TX',
#                                                 'uid': 5447394,
#                                                 'zip_code': '75229'},
#                                             {   'address': '4419 Northcrest',
#                                                 'amount': 593.55,
#                                                 'country': 'US',
#                                                 'created': '2011-05-26 '
#                                                            '01:13:03',
#                                                 'event': 1672023,
#                                                 'name': 'Troop 125',
#                                                 'state': 'TX',
#                                                 'uid': 5447394,
#                                                 'zip_code': '75229'},
#                                             {   'address': '',
#                                                 'amount': 1002.96,
#                                                 'country': 'US',
#                                                 'created': '2011-09-02 '
#                                                            '01:13:14',
#                                                 'event': 2044507,
#                                                 'name': '',
#                                                 'state': '',
#                                                 'uid': 5447394,
#                                                 'zip_code': ''},
#                                             {   'address': '',
#                                                 'amount': 886.94,
#                                                 'country': 'US',
#                                                 'created': '2011-09-17 '
#                                                            '01:11:06',
#                                                 'event': 2061271,
#                                                 'name': '',
#                                                 'state': '',
#                                                 'uid': 5447394,
#                                                 'zip_code': ''},
#                                             {   'address': '',
#                                                 'amount': 1026.56,
#                                                 'country': 'US',
#                                                 'created': '2011-09-23 '
#                                                            '01:11:03',
#                                                 'event': 2154032,
#                                                 'name': '',
#                                                 'state': '',
#                                                 'uid': 5447394,
#                                                 'zip_code': ''},
#                                             {   'address': '',
#                                                 'amount': 316.56,
#                                                 'country': 'US',
#                                                 'created': '2011-10-21 '
#                                                            '01:11:24',
#                                                 'event': 2297492,
#                                                 'name': '',
#                                                 'state': '',
#                                                 'uid': 5447394,
#                                                 'zip_code': ''},
#                                             {   'address': '',
#                                                 'amount': 1566.72,
#                                                 'country': 'US',
#                                                 'created': '2011-11-18 '
#                                                            '03:11:57',
#                                                 'event': 2457192,
#                                                 'name': '',
#                                                 'state': '',
#                                                 'uid': 5447394,
#                                                 'zip_code': ''},
#                                             {   'address': '',
#                                                 'amount': 1379.44,
#                                                 'country': 'US',
#                                                 'created': '2011-12-09 '
#                                                            '03:11:52',
#                                                 'event': 2563874,
#                                                 'name': '',
#                                                 'state': '',
#                                                 'uid': 5447394,
#                                                 'zip_code': ''},
#                                             {   'address': '',
#                                                 'amount': 5276.32,
#                                                 'country': 'US',
#                                                 'created': '2012-01-21 '
#                                                            '03:11:42',
#                                                 'event': 2696481,
#                                                 'name': '',
#                                                 'state': '',
#                                                 'uid': 5447394,
#                                                 'zip_code': ''},
#                                             {   'address': '',
#                                                 'amount': 321.48,
#                                                 'country': 'US',
#                                                 'created': '2012-02-23 '
#                                                            '03:12:36',
#                                                 'event': 2941861,
#                                                 'name': '',
#                                                 'state': '',
#                                                 'uid': 5447394,
#                                                 'zip_code': ''},
#                                             {   'address': '',
#                                                 'amount': 1444.74,
#                                                 'country': 'US',
#                                                 'created': '2012-03-07 '
#                                                            '00:00:00',
#                                                 'event': 2644601,
#                                                 'name': '',
#                                                 'state': '',
#                                                 'uid': 5447394,
#                                                 'zip_code': ''},
#                                             {   'address': '',
#                                                 'amount': 1791.35,
#                                                 'country': 'US',
#                                                 'created': '2012-03-07 '
#                                                            '00:00:00',
#                                                 'event': 2795183,
#                                                 'name': '',
#                                                 'state': '',
#                                                 'uid': 5447394,
#                                                 'zip_code': ''},
#                                             {   'address': '',
#                                                 'amount': 1069.33,
#                                                 'country': 'US',
#                                                 'created': '2012-03-30 '
#                                                            '03:12:35',
#                                                 'event': 3080143,
#                                                 'name': '',
#                                                 'state': '',
#                                                 'uid': 5447394,
#                                                 'zip_code': ''},
#                                             {   'address': '',
#                                                 'amount': 701.53,
#                                                 'country': 'US',
#                                                 'created': '2012-04-24 '
#                                                            '03:13:44',
#                                                 'event': 3344865,
#                                                 'name': '',
#                                                 'state': '',
#                                                 'uid': 5447394,
#                                                 'zip_code': ''},
#                                             {   'address': '',
#                                                 'amount': 800.58,
#                                                 'country': 'US',
#                                                 'created': '2012-05-11 '
#                                                            '03:13:44',
#                                                 'event': 3443671,
#                                                 'name': '',
#                                                 'state': '',
#                                                 'uid': 5447394,
#                                                 'zip_code': ''},
#                                             {   'address': '4419 Northcrest',
#                                                 'amount': 262.26,
#                                                 'country': 'US',
#                                                 'created': '2012-06-09 '
#                                                            '03:14:19',
#                                                 'event': 3595663,
#                                                 'name': 'Troop 125',
#                                                 'state': 'TX',
#                                                 'uid': 5447394,
#                                                 'zip_code': '75229'},
#                                             {   'address': '',
#                                                 'amount': 192.23,
#                                                 'country': 'US',
#                                                 'created': '2012-06-14 '
#                                                            '03:14:22',
#                                                 'event': 3601109,
#                                                 'name': '',
#                                                 'state': '',
#                                                 'uid': 5447394,
#                                                 'zip_code': ''},
#                                             {   'address': '',
#                                                 'amount': 468.52,
#                                                 'country': 'US',
#                                                 'created': '2012-07-05 '
#                                                            '03:13:50',
#                                                 'event': 3357053,
#                                                 'name': '',
#                                                 'state': '',
#                                                 'uid': 5447394,
#                                                 'zip_code': ''},
#                                             {   'address': '',
#                                                 'amount': 1427.44,
#                                                 'country': 'US',
#                                                 'created': '2012-08-31 '
#                                                            '03:14:19',
#                                                 'event': 4135834,
#                                                 'name': '',
#                                                 'state': '',
#                                                 'uid': 5447394,
#                                                 'zip_code': ''}],
#                     'sale_duration': 0.0,
#                     'show_map': 1,
#                     'ticket_types': [   {   'availability': 1,
#                                             'cost': 0.0,
#                                             'event_id': 4320780,
#                                             'quantity_total': 300},
#                                         {   'availability': 1,
#                                             'cost': 117.13,
#                                             'event_id': 4320780,
#                                             'quantity_total': 300},
#                                         {   'availability': 1,
#                                             'cost': 13.18,
#                                             'event_id': 4320780,
#                                             'quantity_total': 300},
#                                         {   'availability': 1,
#                                             'cost': 10.35,
#                                             'event_id': 4320780,
#                                             'quantity_total': 300}],
#                     'user_age': 767,
#                     'user_created': 1281117406,
#                     'user_type': 3,
#                     'venue_address': '',
#                     'venue_country': None,
#                     'venue_latitude': None,
#                     'venue_longitude': None,
#                     'venue_name': None,
#                     'venue_state': None}]}
